# %%
import h5py
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import sys
sys.path.insert(0, './epg')
import epg

import time
import joblib
import sigpy.plot as pl

# %%
mrf_dict = scipy.io.loadmat('/mikRAID/jtamir/projects/MRF_direct_contrast_synthesis/data/DictionaryAndSequenceInfo/fp_dictionary.mat')
print(mrf_dict.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'fp_dict', 't1_list', 't2_list'])

# %%
fp_dict = mrf_dict['fp_dict']
t1_list = mrf_dict['t1_list']
t2_list = mrf_dict['t2_list']

# %%
t1 = np.array(t1_list)
t2 = np.array(t2_list)

# %%
from numpy.random import multivariate_normal

# %%
data.shape
# Out:
# (101000, 2)

# %%
data = np.vstack([
    multivariate_normal([10, 10], [[3, 2], [2, 3]], size=100000),
    multivariate_normal([30, 20], [[2, 3], [1, 3]], size=1000)
])

gammas = [0.8, 0.5, 0.3]

fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0, 0].set_title('Linear normalization')
axes[0, 0].hist2d(data[:, 0], data[:, 1], bins=100)

for ax, gamma in zip(axes.flat[1:], gammas):
    ax.set_title(r'Power law $(\gamma=%1.1f)$' % gamma)
    ax.hist2d(data[:, 0], data[:, 1],
              bins=100, norm=mcolors.PowerNorm(gamma))

fig.tight_layout()

plt.show()
# Out:
# /home/kewang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: covariance is not positive-semidefinite.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# Out:
# numpy.ndarray

# %%
dis_2d = np.histogram2d(t1,t2)

# %%
dis_2d
# Out:
# (array([[2641.,   45.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,
#             0.],
#         [2370.,  545.,  170.,    0.,    0.,    0.,    0.,    0.,    0.,
#             0.],
#         [2370.,  600.,  450.,  200.,   25.,    0.,    0.,    0.,    0.,
#             0.],
#         [1580.,  400.,  300.,  200.,  175.,   25.,    0.,    0.,    0.,
#             0.],
#         [1185.,  300.,  225.,  150.,  150.,   75.,   50.,    6.,    0.,
#             0.],
#         [1106.,  280.,  210.,  140.,  140.,   70.,   70.,   64.,   20.,
#             0.],
#         [1027.,  260.,  195.,  130.,  130.,   65.,   65.,   65.,   65.,
#            35.],
#         [ 632.,  160.,  120.,   80.,   80.,   40.,   40.,   40.,   40.,
#            40.],
#         [ 553.,  140.,  105.,   70.,   70.,   35.,   35.,   35.,   35.,
#            35.],
#         [ 632.,  160.,  120.,   80.,   80.,   40.,   40.,   40.,   40.,
#            40.]]),
#  array([   4. ,  299.6,  595.2,  890.8, 1186.4, 1482. , 1777.6, 2073.2,
#         2368.8, 2664.4, 2960. ]),
#  array([   2. ,  197.8,  393.6,  589.4,  785.2,  981. , 1176.8, 1372.6,
#         1568.4, 1764.2, 1960. ]))

# %%
plt.hist2d(t1,t2,bins = 100)
# Out:
# (array([[105.,  15.,   0., ...,   0.,   0.,   0.],
#         [150., 140.,  55., ...,   0.,   0.,   0.],
#         [150., 150., 150., ...,   0.,   0.,   0.],
#         ...,
#         [ 10.,  10.,  10., ...,   1.,   0.,   1.],
#         [ 10.,  10.,  10., ...,   1.,   0.,   1.],
#         [ 10.,  10.,  10., ...,   1.,   0.,   1.]]),
#  array([   4.  ,   33.56,   63.12,   92.68,  122.24,  151.8 ,  181.36,
#          210.92,  240.48,  270.04,  299.6 ,  329.16,  358.72,  388.28,
#          417.84,  447.4 ,  476.96,  506.52,  536.08,  565.64,  595.2 ,
#          624.76,  654.32,  683.88,  713.44,  743.  ,  772.56,  802.12,
#          831.68,  861.24,  890.8 ,  920.36,  949.92,  979.48, 1009.04,
#         1038.6 , 1068.16, 1097.72, 1127.28, 1156.84, 1186.4 , 1215.96,
#         1245.52, 1275.08, 1304.64, 1334.2 , 1363.76, 1393.32, 1422.88,
#         1452.44, 1482.  , 1511.56, 1541.12, 1570.68, 1600.24, 1629.8 ,
#         1659.36, 1688.92, 1718.48, 1748.04, 1777.6 , 1807.16, 1836.72,
#         1866.28, 1895.84, 1925.4 , 1954.96, 1984.52, 2014.08, 2043.64,
#         2073.2 , 2102.76, 2132.32, 2161.88, 2191.44, 2221.  , 2250.56,
#         2280.12, 2309.68, 2339.24, 2368.8 , 2398.36, 2427.92, 2457.48,
#         2487.04, 2516.6 , 2546.16, 2575.72, 2605.28, 2634.84, 2664.4 ,
#         2693.96, 2723.52, 2753.08, 2782.64, 2812.2 , 2841.76, 2871.32,
#         2900.88, 2930.44, 2960.  ]),
#  array([   2.  ,   21.58,   41.16,   60.74,   80.32,   99.9 ,  119.48,
#          139.06,  158.64,  178.22,  197.8 ,  217.38,  236.96,  256.54,
#          276.12,  295.7 ,  315.28,  334.86,  354.44,  374.02,  393.6 ,
#          413.18,  432.76,  452.34,  471.92,  491.5 ,  511.08,  530.66,
#          550.24,  569.82,  589.4 ,  608.98,  628.56,  648.14,  667.72,
#          687.3 ,  706.88,  726.46,  746.04,  765.62,  785.2 ,  804.78,
#          824.36,  843.94,  863.52,  883.1 ,  902.68,  922.26,  941.84,
#          961.42,  981.  , 1000.58, 1020.16, 1039.74, 1059.32, 1078.9 ,
#         1098.48, 1118.06, 1137.64, 1157.22, 1176.8 , 1196.38, 1215.96,
#         1235.54, 1255.12, 1274.7 , 1294.28, 1313.86, 1333.44, 1353.02,
#         1372.6 , 1392.18, 1411.76, 1431.34, 1450.92, 1470.5 , 1490.08,
#         1509.66, 1529.24, 1548.82, 1568.4 , 1587.98, 1607.56, 1627.14,
#         1646.72, 1666.3 , 1685.88, 1705.46, 1725.04, 1744.62, 1764.2 ,
#         1783.78, 1803.36, 1822.94, 1842.52, 1862.1 , 1881.68, 1901.26,
#         1920.84, 1940.42, 1960.  ]),
#  <matplotlib.collections.QuadMesh at 0x7fcc2bdff978>)

# %%
t1 = np.array(t1_list)[:,0]
t2 = np.array(t2_list)[:,0]

# %%
plt.hist2d(np.array(t1_list),np.array(t2_list),10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in histogramdd(sample, bins, range, normed, weights)
#     900         # Sample is an ND-array.
# --> 901         N, D = sample.shape
#     902     except (AttributeError, ValueError):
#
# AttributeError: 'list' object has no attribute 'shape'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-3c071c4db219> in <module>()
# ----> 1 plt.hist2d(np.array(t1_list),np.array(t2_list),10)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in hist2d(x, y, bins, range, normed, weights, cmin, cmax, data, **kwargs)
#    2670         x, y, bins=bins, range=range, normed=normed, weights=weights,
#    2671         cmin=cmin, cmax=cmax, **({"data": data} if data is not None
# -> 2672         else {}), **kwargs)
#    2673     sci(__ret[-1])
#    2674     return __ret
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist2d(self, x, y, bins, range, normed, weights, cmin, cmax, **kwargs)
#    6887
#    6888         h, xedges, yedges = np.histogram2d(x, y, bins=bins, range=range,
# -> 6889                                            normed=normed, weights=weights)
#    6890
#    6891         if cmin is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/twodim_base.py in histogram2d(x, y, bins, range, normed, weights)
#     653         xedges = yedges = asarray(bins, float)
#     654         bins = [xedges, yedges]
# --> 655     hist, edges = histogramdd([x, y], bins, range, normed, weights)
#     656     return hist, edges[0], edges[1]
#     657
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in histogramdd(sample, bins, range, normed, weights)
#     903         # Sample is a sequence of 1D arrays.
#     904         sample = atleast_2d(sample).T
# --> 905         N, D = sample.shape
#     906
#     907     nbin = empty(D, int)
#
# ValueError: too many values to unpack (expected 2)

# %%
plt.figure
plt.plot(t1_list,t2_list,'*')
plt.show()
