# %%
# import sigpy.plot as pl
import numpy as np
import torch
import torch.backends.cudnn as cudnn
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
import scipy.io
from torch.autograd import Variable
# % matplotlib notebook
import matplotlib.pyplot as plt

# %%
mrf_dict = scipy.io.loadmat('/mikRAID/jtamir/projects/MRF_direct_contrast_synthesis/data/DictionaryAndSequenceInfo/fp_dictionary.mat')
# print(MRF_dic.keys())
fp_dict = mrf_dict['fp_dict']
t1_list = mrf_dict['t1_list']
t2_list = mrf_dict['t2_list']
N_dict = t1_list.shape[0]

# %%
# not sure what this is doin
# def read_flipangles(flip_file):
#     f = open(flip_file)
#     flips =  [float(a) for a in f.readlines()]
#     f.close()
#     return np.array(flips)
# flips = read_flipangles('/mikRAID/jtamir/projects/MRF_direct_contrast_synthesis/data/DictionaryAndSequenceInfo/flipangles.txt')
# N_flip = len(flips)
# fp_dic = np.hstack(list(fp_dict[0][0])).reshape((N_flip, 2, N_dict)).transpose((0, 2, 1))
# fp_dic = np.abs(fp_dic[:,:,0] + 1j * fp_dic[:,:,1])
# print(fp_dic.shape)

# %%
plt.plot(fp_dict[0][0][0])
plt.show()

# %%
plt.plot(fp_dict[0][0][1])
plt.show()

# %%
T1_test = np.load("/mikQNAP/augmented_data/T1w/T1_norm_volunteer1_1.npy")[0]

# %%
thresh = np.percentile(T1_test,95)
T1_test[T1_test>thresh]=thresh

# %%
plt.figure(figsize=(10,10))
a = plt.hist(T1_test.flatten(),bins="auto")

# %%
T1[T10]

# %%
T1 = cv2.equalizeHist(T1)

# %%
plt.figure(figsize=(10,10))
plt.hist(T1.flatten(),bins="auto")
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 3.310e+04,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.505e+04, 0.000e+00, 5.048e+03, 1.361e+03, 2.189e+03,
#         1.887e+03, 1.861e+03, 1.677e+03, 2.073e+03, 1.437e+03, 1.762e+03,
#         2.377e+03, 2.170e+03, 1.567e+03, 1.824e+03, 1.965e+03, 2.095e+03,
#         2.141e+03, 1.010e+03, 2.008e+03, 2.130e+03, 2.070e+03, 2.059e+03,
#         2.060e+03, 1.093e+03, 2.023e+03, 2.529e+03, 2.021e+03, 1.812e+03]),
#  array([  0.        ,   4.72222222,   9.44444444,  14.16666667,
#          18.88888889,  23.61111111,  28.33333333,  33.05555556,
#          37.77777778,  42.5       ,  47.22222222,  51.94444444,
#          56.66666667,  61.38888889,  66.11111111,  70.83333333,
#          75.55555556,  80.27777778,  85.        ,  89.72222222,
#          94.44444444,  99.16666667, 103.88888889, 108.61111111,
#         113.33333333, 118.05555556, 122.77777778, 127.5       ,
#         132.22222222, 136.94444444, 141.66666667, 146.38888889,
#         151.11111111, 155.83333333, 160.55555556, 165.27777778,
#         170.        , 174.72222222, 179.44444444, 184.16666667,
#         188.88888889, 193.61111111, 198.33333333, 203.05555556,
#         207.77777778, 212.5       , 217.22222222, 221.94444444,
#         226.66666667, 231.38888889, 236.11111111, 240.83333333,
#         245.55555556, 250.27777778, 255.        ]),
#  <a list of 54 Patch objects>)

# %%
import numpy as np
np.info(np.load("data/MRF_test/MRF_norm_volunteer12_1.npy"))
# Out:
# class:  ndarray
# shape:  (320, 320, 1000)
# strides:  (4, 1280, 409600)
# itemsize:  4
# aligned:  True
# contiguous:  False
# fortran:  True
# data pointer: 0x7f2a995ca040
# byteorder:  little
# byteswap:  False
# type: float32

# %%
T2_file = np.load("data/T1w_test/T1_norm_volunteer12_1.npy", mmap_mode="r")

# %%
T2_file[0,0,:]
# Out:
# memmap([309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309,
#         309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309,
#         309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309,
#         309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309,
#         309, 309, 309, 309, 309, 305, 310, 309, 309, 309, 336, 366, 483,
#         286, 343, 460, 423, 480, 478, 375, 390, 410, 320, 303, 310, 309,
#         309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309,
#         309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309,
#         309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309,
#         309, 309, 309, 304, 410, 508, 462, 436, 514, 523, 524, 582, 496,
#         368, 472, 471, 467, 450, 605, 480, 440, 484, 507, 469, 632, 456,
#         460, 430, 425, 523, 466, 480, 693, 536, 470, 460, 599, 576, 377,
#         476, 385, 362, 317, 354, 412, 385, 422, 468, 434, 358, 482, 462,
#         344, 423, 467, 407, 424, 324, 448, 479, 332, 486, 439, 470, 491,
#         375, 472, 399, 337, 568, 561, 462, 305, 433, 360, 381, 465, 341,
#         401, 309, 305, 309, 309, 309, 309, 309, 309, 406, 349, 369, 394,
#         430, 362, 484, 471, 466, 468, 412, 485, 434, 348, 355, 356, 360,
#         428, 363, 354, 302, 304, 292, 417, 496, 465, 524, 592, 456, 519,
#         479, 524, 626, 577, 568, 450, 334, 392, 499, 519, 468, 473, 472,
#         447, 484, 409, 476, 319, 309, 309, 309, 309, 309, 309, 309, 309,
#         309, 309, 309, 309, 309, 309, 310, 305, 314, 302, 448, 353, 439,
#         295, 304, 338, 474, 479, 468, 361, 350, 376, 305, 309, 309, 309,
#         309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309,
#         309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309, 309,
#         309, 309, 309, 309, 309, 309, 309, 309], dtype=uint16)
